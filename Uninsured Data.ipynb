# %%
#imports
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#file paths
csv_2018 = pd.read_csv("C:/Users/Sydney/Desktop/Group-Project/resources/2018_HI_csv.csv", header=[7])
csv_2019 = pd.read_csv("C:/Users/Sydney/Desktop/Group-Project/resources/2019_HI_csv.csv", header=[9] )
csv_2020 = pd.read_csv("C:/Users/Sydney/Desktop/Group-Project/resources/2020_HI_csv.csv", header=[8])
csv_2021 = pd.read_csv("C:/Users/Sydney/Desktop/Group-Project/resources/2021_HI_csv.csv", header=[8])

# %%
csv_2018.columns = ['Characteristic', 'Total', 'Any Number', 'Any MOE', 'Any Percent', 'Any MOE',
              'Private Total Number', 'Private Number MOE', 'Private Total Percent', 'Private Percent MOE',
              'Employment Based Number', 'Employment Based Number MOE', 'Employment Based Percent', 'Employment Based Percent MOE',
              'Direct Purchase Number', 'Direct Purchase Number MOE', 'Direct Purchase Percent', 'Direct Purchase Percent MOE',
              'Tricare Number', 'Tricare Number MOE', 'Tricare Percent', 'Tricare Percent MOE',
              'Public Total Number', 'Public Number MOE', 'Public Total Percent', 'Public Percent MOE',
              'Medicare Number', 'Medicare Number MOE', 'Medicare Percent', 'Medicare Percent MOE',
              'Medicaid Number', 'Medicaid Number MOE', 'Medicaid Percent', 'Medicaid Percent MOE',
              'VA/CHAMPVA Number', 'VA/CHAMPVA Number MOE', 'VA/CHAMPVA Percent', 'VA/CHAMPVA Percent MOE',
              'Uninsured Number', 'Uninsured Number MOE', 'Uninsured Percent', 'Uninsured Percent MOE']

# %%
uninsured2018_csv = csv_2018[['Characteristic', 'Total', 'Uninsured Number', 'Uninsured Number MOE', 'Uninsured Percent', 'Uninsured Percent MOE']]

# %%
uninsured2018_csv
# Out:
#                                         Characteristic    Total  \
# 0                                                Total  323,668
# 1                                        Family Status      NaN
# 2                                          In families  261,336
# 3                                         .Householder   83,508
# 4                           .Related children under 18   71,750
# ..                                                 ...      ...
# 104  5 Individuals aged 19 to 25 years may be eligi...      NaN
# 105  6The sum of those with and without a disabilit...      NaN
# 106  7The "Outside metropolitan statistical areas" ...      NaN
# 107  Source:  U.S. Census Bureau, Current Populatio...      NaN
# 108                                                NaN      NaN
#
#     Uninsured Number  Uninsured Number MOE  Uninsured Percent  \
# 0             27,462                 630.0                8.5
# 1                NaN                   NaN                NaN
# 2             20,540                 551.0                7.9
# 3              6,376                 217.0                7.6
# 4              3,774                 209.0                5.3
# ..               ...                   ...                ...
# 104              NaN                   NaN                NaN
# 105              NaN                   NaN                NaN
# 106              NaN                   NaN                NaN
# 107              NaN                   NaN                NaN
# 108              NaN                   NaN                NaN
#
#      Uninsured Percent MOE
# 0                      0.2
# 1                      NaN
# 2                      0.2
# 3                      0.3
# 4                      0.3
# ..                     ...
# 104                    NaN
# 105                    NaN
# 106                    NaN
# 107                    NaN
# 108                    NaN
#
# [109 rows x 6 columns]

# %%
csv_2019.columns = ['Characteristic', 'Total', 'Any Number', 'Any MOE', 'Any Percent', 'Any MOE',
              'Private Total Number', 'Private Number MOE', 'Private Total Percent', 'Private Percent MOE',
              'Employment Based Number', 'Employment Based Number MOE', 'Employment Based Percent', 'Employment Based Percent MOE',
              'Direct Purchase Number', 'Direct Purchase Number MOE', 'Direct Purchase Percent', 'Direct Purchase Percent MOE',
              'Tricare Number', 'Tricare Number MOE', 'Tricare Percent', 'Tricare Percent MOE',
              'Public Total Number', 'Public Number MOE', 'Public Total Percent', 'Public Percent MOE',
              'Medicare Number', 'Medicare Number MOE', 'Medicare Percent', 'Medicare Percent MOE',
              'Medicaid Number', 'Medicaid Number MOE', 'Medicaid Percent', 'Medicaid Percent MOE',
              'VA/CHAMPVA Number', 'VA/CHAMPVA Number MOE', 'VA/CHAMPVA Percent', 'VA/CHAMPVA Percent MOE',
              'Uninsured Number', 'Uninsured Number MOE', 'Uninsured Percent', 'Uninsured Percent MOE']

# %%
uninsured2019_csv = csv_2019[['Characteristic', 'Total', 'Uninsured Number', 'Uninsured Number MOE', 'Uninsured Percent', 'Uninsured Percent MOE']]

# %%
uninsured2019_csv
# Out:
#                                         Characteristic    Total  \
# 0                                                Total  324,550
# 1                                        Family Status      NaN
# 2                                          In families  262,991
# 3                                        ..Householder   83,698
# 4                          ..Related children under 18   71,148
# ..                                                 ...      ...
# 102  4 Children under the age of 19 are eligible fo...      NaN
# 103  5 Children born after the reference year are n...      NaN
# 104  6 This age group is of special interest becaus...      NaN
# 105  7 The sum of those with and without a disabili...      NaN
# 106  8 The "Outside metropolitan statistical areas"...      NaN
#
#     Uninsured Number  Uninsured Number MOE  Uninsured Percent  \
# 0             26,111                 657.0                8.0
# 1                NaN                   NaN                NaN
# 2             19,480                 586.0                7.4
# 3              5,800                 201.0                6.9
# 4              3,552                 211.0                5.0
# ..               ...                   ...                ...
# 102              NaN                   NaN                NaN
# 103              NaN                   NaN                NaN
# 104              NaN                   NaN                NaN
# 105              NaN                   NaN                NaN
# 106              NaN                   NaN                NaN
#
#      Uninsured Percent MOE
# 0                      0.2
# 1                      NaN
# 2                      0.2
# 3                      0.2
# 4                      0.3
# ..                     ...
# 102                    NaN
# 103                    NaN
# 104                    NaN
# 105                    NaN
# 106                    NaN
#
# [107 rows x 6 columns]

# %%
csv_2020.columns = ['Characteristic', 'Total', 'Any Number', 'Any MOE', 'Any Percent', 'Any MOE',
              'Private Total Number', 'Private Number MOE', 'Private Total Percent', 'Private Percent MOE',
              'Employment Based Number', 'Employment Based Number MOE', 'Employment Based Percent', 'Employment Based Percent MOE',
              'Direct Purchase Number', 'Direct Purchase Number MOE', 'Direct Purchase Percent', 'Direct Purchase Percent MOE',
              'Tricare Number', 'Tricare Number MOE', 'Tricare Percent', 'Tricare Percent MOE',
              'Public Total Number', 'Public Number MOE', 'Public Total Percent', 'Public Percent MOE',
              'Medicare Number', 'Medicare Number MOE', 'Medicare Percent', 'Medicare Percent MOE',
              'Medicaid Number', 'Medicaid Number MOE', 'Medicaid Percent', 'Medicaid Percent MOE',
              'VA/CHAMPVA Number', 'VA/CHAMPVA Number MOE', 'VA/CHAMPVA Percent', 'VA/CHAMPVA Percent MOE',
              'Uninsured Number', 'Uninsured Number MOE', 'Uninsured Percent', 'Uninsured Percent MOE']

# %%
uninsured2020_csv = csv_2020[['Characteristic', 'Total', 'Uninsured Number', 'Uninsured Number MOE', 'Uninsured Percent', 'Uninsured Percent MOE']]

# %%
uninsured2020_csv
# Out:
#                                         Characteristic    Total  \
# 0                                                Total  325,638
# 1                                        Family Status      NaN
# 2                                          In families  261,847
# 3                                        ..Householder   83,918
# 4                          ..Related children under 18   70,976
# ..                                                 ...      ...
# 103  4 Children under the age of 19 are eligible fo...      NaN
# 104  5 Children born after the reference year are n...      NaN
# 105  6 This age group is of special interest becaus...      NaN
# 106  7 The sum of those with and without a disabili...      NaN
# 107  8 The "Outside metropolitan statistical areas"...      NaN
#
#     Uninsured Number  Uninsured Number MOE  Uninsured Percent  \
# 0             27,957                 612.0                8.6
# 1                NaN                   NaN                NaN
# 2             21,255                 521.0                8.1
# 3              6,414                 184.0                7.6
# 4              3,861                 210.0                5.4
# ..               ...                   ...                ...
# 103              NaN                   NaN                NaN
# 104              NaN                   NaN                NaN
# 105              NaN                   NaN                NaN
# 106              NaN                   NaN                NaN
# 107              NaN                   NaN                NaN
#
#      Uninsured Percent MOE
# 0                      0.2
# 1                      NaN
# 2                      0.2
# 3                      0.2
# 4                      0.3
# ..                     ...
# 103                    NaN
# 104                    NaN
# 105                    NaN
# 106                    NaN
# 107                    NaN
#
# [108 rows x 6 columns]

# %%
csv_2021.columns = ['Characteristic', 'Total', 'Any Number', 'Any MOE', 'Any Percent', 'Any MOE',
              'Private Total Number', 'Private Number MOE', 'Private Total Percent', 'Private Percent MOE',
              'Employment Based Number', 'Employment Based Number MOE', 'Employment Based Percent', 'Employment Based Percent MOE',
              'Direct Purchase Number', 'Direct Purchase Number MOE', 'Direct Purchase Percent', 'Direct Purchase Percent MOE',
              'Tricare Number', 'Tricare Number MOE', 'Tricare Percent', 'Tricare Percent MOE',
              'Public Total Number', 'Public Number MOE', 'Public Total Percent', 'Public Percent MOE',
              'Medicare Number', 'Medicare Number MOE', 'Medicare Percent', 'Medicare Percent MOE',
              'Medicaid Number', 'Medicaid Number MOE', 'Medicaid Percent', 'Medicaid Percent MOE',
              'VA/CHAMPVA Number', 'VA/CHAMPVA Number MOE', 'VA/CHAMPVA Percent', 'VA/CHAMPVA Percent MOE',
              'Uninsured Number', 'Uninsured Number MOE', 'Uninsured Percent', 'Uninsured Percent MOE']

# %%
uninsured2021_csv = csv_2021[['Characteristic', 'Total', 'Uninsured Number', 'Uninsured Number MOE', 'Uninsured Percent', 'Uninsured Percent MOE']]

# %%
uninsured2021_csv
# Out:
#                                         Characteristic    Total  \
# 0                                                Total  328,074
# 1                                        Family Status      NaN
# 2                                          In families  263,127
# 3                                        ..Householder   84,283
# 4                          ..Related children under 18   71,491
# ..                                                 ...      ...
# 103  4 Children under the age of 19 are eligible fo...      NaN
# 104  5 Children born after the reference year are n...      NaN
# 105  6 This age group is of special interest becaus...      NaN
# 106  7 The sum of those with and without a disabili...      NaN
# 107  8 The "Outside metropolitan statistical areas"...      NaN
#
#     Uninsured Number  Uninsured Number MOE  Uninsured Percent  \
# 0             27,187                 727.0                8.3
# 1                NaN                   NaN                NaN
# 2             20,214                 648.0                7.7
# 3              6,187                 219.0                7.3
# 4              3,444                 227.0                4.8
# ..               ...                   ...                ...
# 103              NaN                   NaN                NaN
# 104              NaN                   NaN                NaN
# 105              NaN                   NaN                NaN
# 106              NaN                   NaN                NaN
# 107              NaN                   NaN                NaN
#
#      Uninsured Percent MOE
# 0                      0.2
# 1                      NaN
# 2                      0.2
# 3                      0.3
# 4                      0.3
# ..                     ...
# 103                    NaN
# 104                    NaN
# 105                    NaN
# 106                    NaN
# 107                    NaN
#
# [108 rows x 6 columns]

# %%
uninsuredtotal_2018 = uninsured2018_csv['Uninsured Number'].values[0]
uninsuredtotal_2019 = uninsured2019_csv['Uninsured Number'].values[0]
uninsuredtotal_2020 = uninsured2020_csv['Uninsured Number'].values[0]
uninsuredtotal_2021 = uninsured2021_csv['Uninsured Number'].values[0]

years = ["2018", "2019", "2020", "2021"]
UItotals = [uninsuredtotal_2018, uninsuredtotal_2019, uninsured2020_csv, uninsuredtotal_2021]

# %%
yearlyuninsured_compare= plt.plot(years,UItotals)
yearlyuninsured_compare
# Out:
# c:\Users\Sydney\anaconda3\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 yearlyuninsured_compare= plt.plot(years,UItotals)
#       2 yearlyuninsured_compare
#
# File c:\Users\Sydney\anaconda3\lib\site-packages\matplotlib\pyplot.py:2785, in plot(scalex, scaley, data, *args, **kwargs)
#    2783 @_copy_docstring_and_deprecators(Axes.plot)
#    2784 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2785     return gca().plot(
#    2786         *args, scalex=scalex, scaley=scaley,
#    2787         **({"data": data} if data is not None else {}), **kwargs)
#
# File c:\Users\Sydney\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
#    1687 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
#    1690     self.add_line(line)
#
# File c:\Users\Sydney\anaconda3\lib\site-packages\matplotlib\axes\_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File c:\Users\Sydney\anaconda3\lib\site-packages\matplotlib\axes\_base.py:501, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     499     self.axes.xaxis.update_units(x)
#     500 if self.axes.yaxis is not None:
# --> 501     self.axes.yaxis.update_units(y)
#     503 if x.shape[0] != y.shape[0]:
#     504     raise ValueError(f"x and y must have same first dimension, but "
#     505                      f"have shapes {x.shape} and {y.shape}")
#
# File c:\Users\Sydney\anaconda3\lib\site-packages\matplotlib\axis.py:1670, in Axis.update_units(self, data)
#    1668 neednew = self.converter != converter
#    1669 self.converter = converter
# -> 1670 default = self.converter.default_units(data, self)
#    1671 if default is not None and self.units is None:
#    1672     self.set_units(default)
#
# File c:\Users\Sydney\anaconda3\lib\site-packages\matplotlib\category.py:105, in StrCategoryConverter.default_units(data, axis)
#     103 # the conversion call stack is default_units -> axis_info -> convert
#     104 if axis.units is None:
# --> 105     axis.set_units(UnitData(data))
#     106 else:
#     107     axis.units.update(data)
#
# File c:\Users\Sydney\anaconda3\lib\site-packages\matplotlib\category.py:181, in UnitData.__init__(self, data)
#     179 self._counter = itertools.count()
#     180 if data is not None:
# --> 181     self.update(data)
#
# File c:\Users\Sydney\anaconda3\lib\site-packages\matplotlib\category.py:214, in UnitData.update(self, data)
#     212 # check if convertible to number:
#     213 convertible = True
# --> 214 for val in OrderedDict.fromkeys(data):
#     215     # OrderedDict just iterates over unique values in data.
#     216     _api.check_isinstance((str, bytes), value=val)
#     217     if convertible:
#     218         # this will only be called so long as convertible is True.
#
# TypeError: unhashable type: 'DataFrame'
