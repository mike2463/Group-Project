# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt

# %%
data = pd.read_csv('Resources/GDP.csv')
data.head()
# Out:
#          DATE      GDP
# 0  1947-01-01  243.164
# 1  1947-04-01  245.968
# 2  1947-07-01  249.585
# 3  1947-10-01  259.745
# 4  1948-01-01  265.742

# %%
pd.to_datetime(data['DATE'], format= '%Y-%m-%d' )
recent_gdp = data[(data['DATE']>='2018-01-01') & (data['DATE']<='2022-01-01')]
#recent_gdp = recent_gdp.sort_values('GDP')
recent_gdp.dtypes
# Out:
# DATE     object
# GDP     float64
# dtype: object

# %%
recent_gdp['GDP'].describe()
# Out:
# count       17.000000
# mean     21758.755059
# std       1427.372289
# min      19636.731000
# 25%      20819.269000
# 50%      21531.839000
# 75%      22313.850000
# max      24740.480000
# Name: GDP, dtype: float64

# %%
x_axis = recent_gdp['DATE']

y_axis = recent_gdp['GDP'].sort_values(ascending=True)
plt.plot(x_axis,y_axis)
plt.xticks(x_axis, rotation = 90)
plt.ylabel('GDP (billions of dollars)', loc='center')
plt.xlabel('Quarters')
# Out:
# Text(0.5, 0, 'Quarters')

# %%
recent_gdp['Growth'] = np.round(recent_gdp['GDP'].pct_change()*100,2)
recent_gdp.dropna()
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_31092\2996131178.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recent_gdp['Growth'] = np.round(recent_gdp['GDP'].pct_change()*100,2)
#            DATE        GDP  Growth
# 285  2018-04-01  20470.197    1.56
# 286  2018-07-01  20687.278    1.06
# 287  2018-10-01  20819.269    0.64
# 288  2019-01-01  21013.085    0.93
# 289  2019-04-01  21272.448    1.23
# 290  2019-07-01  21531.839    1.22
# 291  2019-10-01  21706.532    0.81
# 292  2020-01-01  21538.032   -0.78
# 293  2020-04-01  19636.731   -8.83
# 294  2020-07-01  21362.428    8.79
# 295  2020-10-01  21704.706    1.60
# 296  2021-01-01  22313.850    2.81
# 297  2021-04-01  23046.934    3.29
# 298  2021-07-01  23550.420    2.18
# 299  2021-10-01  24349.121    3.39
# 300  2022-01-01  24740.480    1.61

# %%
x_axis = recent_gdp['DATE']

y_axis = recent_gdp['Growth'].sort_values(ascending=True)
plt.plot(x_axis,y_axis)
plt.xticks(x_axis, rotation = 90)
plt.ylabel('GDP Growth Rate', loc='center')
plt.xlabel('Quarters')
# Out:
# Text(0.5, 0, 'Quarters')

# %%
recent_gdp.to_csv('GDP')
