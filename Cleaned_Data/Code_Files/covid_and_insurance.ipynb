# %%
import pandas as pd

# %%
covid_df= pd.read_csv('Cleaned_Data\covid_data')
public_insurance_df= pd.read_csv("Cleaned_Data\public_allyears.csv")

# %%
combined_df = pd.concat([covid_df, public_insurance_df])
#combined_df = combined_df.dropna()
public_insurance_df
# Out:
#                            Characteristic Total_x_x Public Total Number_x_x  \
# 0                                   Total   323,668                 111,330
# 1                           Family Status       NaN                     NaN
# 2                             In families   261,336                  85,995
# 3                In unrelated subfamilies     1,069                     453
# 4                   Unrelated individuals    61,264                  24,882
# ..                                    ...       ...                     ...
# 59                               Divorced    18,683                   4,719
# 60                              Separated     4,200                   1,249
# 61                          Never Married    65,475                  14,142
# 62                              Residence       NaN                     NaN
# 63  Inside metropolitan statistical areas   281,369                  93,410
#
# ...
