# %%
#imports
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#file paths
csv_2018 = pd.read_csv("C:/Users/Sydney/Desktop/Group-Project/resources/2018_HI_csv.csv", header=[7])
csv_2019 = pd.read_csv("C:/Users/Sydney/Desktop/Group-Project/resources/2019_HI_csv.csv", header=[9] )
csv_2020 = pd.read_csv("C:/Users/Sydney/Desktop/Group-Project/resources/2020_HI_csv.csv", header=[8])
csv_2021 = pd.read_csv("C:/Users/Sydney/Desktop/Group-Project/resources/2021_HI_csv.csv", header=[8])

# %%
csv_2018.columns = ['Characteristic', 'Total', 'Any Number', 'Any MOE', 'Any Percent', 'Any MOE',
              'Private Total Number', 'Private Number MOE', 'Private Total Percent', 'Private Percent MOE',
              'Employment Based Number', 'Employment Based Number MOE', 'Employment Based Percent', 'Employment Based Percent MOE',
              'Direct Purchase Number', 'Direct Purchase Number MOE', 'Direct Purchase Percent', 'Direct Purchase Percent MOE',
              'Tricare Number', 'Tricare Number MOE', 'Tricare Percent', 'Tricare Percent MOE',
              'Public Total Number', 'Public Number MOE', 'Public Total Percent', 'Public Percent MOE',
              'Medicare Number', 'Medicare Number MOE', 'Medicare Percent', 'Medicare Percent MOE',
              'Medicaid Number', 'Medicaid Number MOE', 'Medicaid Percent', 'Medicaid Percent MOE',
              'VA/CHAMPVA Number', 'VA/CHAMPVA Number MOE', 'VA/CHAMPVA Percent', 'VA/CHAMPVA Percent MOE',
              'Uninsured Number', 'Uninsured Number MOE', 'Uninsured Percent', 'Uninsured Percent MOE']

# %%
uninsured2018_csv = csv_2018[['Characteristic', 'Total', 'Uninsured Number', 'Uninsured Number MOE', 'Uninsured Percent', 'Uninsured Percent MOE']]

# %%
csv_2019.columns = ['Characteristic', 'Total', 'Any Number', 'Any MOE', 'Any Percent', 'Any MOE',
              'Private Total Number', 'Private Number MOE', 'Private Total Percent', 'Private Percent MOE',
              'Employment Based Number', 'Employment Based Number MOE', 'Employment Based Percent', 'Employment Based Percent MOE',
              'Direct Purchase Number', 'Direct Purchase Number MOE', 'Direct Purchase Percent', 'Direct Purchase Percent MOE',
              'Tricare Number', 'Tricare Number MOE', 'Tricare Percent', 'Tricare Percent MOE',
              'Public Total Number', 'Public Number MOE', 'Public Total Percent', 'Public Percent MOE',
              'Medicare Number', 'Medicare Number MOE', 'Medicare Percent', 'Medicare Percent MOE',
              'Medicaid Number', 'Medicaid Number MOE', 'Medicaid Percent', 'Medicaid Percent MOE',
              'VA/CHAMPVA Number', 'VA/CHAMPVA Number MOE', 'VA/CHAMPVA Percent', 'VA/CHAMPVA Percent MOE',
              'Uninsured Number', 'Uninsured Number MOE', 'Uninsured Percent', 'Uninsured Percent MOE']

# %%
uninsured2019_csv = csv_2019[['Characteristic', 'Total', 'Uninsured Number', 'Uninsured Number MOE', 'Uninsured Percent', 'Uninsured Percent MOE']]

# %%
csv_2020.columns = ['Characteristic', 'Total', 'Any Number', 'Any MOE', 'Any Percent', 'Any MOE',
              'Private Total Number', 'Private Number MOE', 'Private Total Percent', 'Private Percent MOE',
              'Employment Based Number', 'Employment Based Number MOE', 'Employment Based Percent', 'Employment Based Percent MOE',
              'Direct Purchase Number', 'Direct Purchase Number MOE', 'Direct Purchase Percent', 'Direct Purchase Percent MOE',
              'Tricare Number', 'Tricare Number MOE', 'Tricare Percent', 'Tricare Percent MOE',
              'Public Total Number', 'Public Number MOE', 'Public Total Percent', 'Public Percent MOE',
              'Medicare Number', 'Medicare Number MOE', 'Medicare Percent', 'Medicare Percent MOE',
              'Medicaid Number', 'Medicaid Number MOE', 'Medicaid Percent', 'Medicaid Percent MOE',
              'VA/CHAMPVA Number', 'VA/CHAMPVA Number MOE', 'VA/CHAMPVA Percent', 'VA/CHAMPVA Percent MOE',
              'Uninsured Number', 'Uninsured Number MOE', 'Uninsured Percent', 'Uninsured Percent MOE']

# %%
uninsured2020_csv = csv_2020[['Characteristic', 'Total', 'Uninsured Number', 'Uninsured Number MOE', 'Uninsured Percent', 'Uninsured Percent MOE']]

# %%
csv_2021.columns = ['Characteristic', 'Total', 'Any Number', 'Any MOE', 'Any Percent', 'Any MOE',
              'Private Total Number', 'Private Number MOE', 'Private Total Percent', 'Private Percent MOE',
              'Employment Based Number', 'Employment Based Number MOE', 'Employment Based Percent', 'Employment Based Percent MOE',
              'Direct Purchase Number', 'Direct Purchase Number MOE', 'Direct Purchase Percent', 'Direct Purchase Percent MOE',
              'Tricare Number', 'Tricare Number MOE', 'Tricare Percent', 'Tricare Percent MOE',
              'Public Total Number', 'Public Number MOE', 'Public Total Percent', 'Public Percent MOE',
              'Medicare Number', 'Medicare Number MOE', 'Medicare Percent', 'Medicare Percent MOE',
              'Medicaid Number', 'Medicaid Number MOE', 'Medicaid Percent', 'Medicaid Percent MOE',
              'VA/CHAMPVA Number', 'VA/CHAMPVA Number MOE', 'VA/CHAMPVA Percent', 'VA/CHAMPVA Percent MOE',
              'Uninsured Number', 'Uninsured Number MOE', 'Uninsured Percent', 'Uninsured Percent MOE']

# %%
uninsured2021_csv = csv_2021[['Characteristic', 'Total', 'Uninsured Number', 'Uninsured Number MOE', 'Uninsured Percent', 'Uninsured Percent MOE']]

# %%
uninsured2018_csv.to_csv('2018_unins.csv', index=False)
uninsured2019_csv.to_csv('2019_unins.csv', index=False)
uninsured2020_csv.to_csv('2020_unins.csv', index=False)
uninsured2021_csv.to_csv('2021_unins.csv', index=False)

# %%
merge_ui1819= pd.merge(uninsured2018_csv,uninsured2019_csv, on='Characteristic')

# %%
merge_ui2021= pd.merge(uninsured2020_csv,uninsured2021_csv, on='Characteristic')

# %%
ui_allyears= pd.merge(merge_ui1819,merge_ui2021, on='Characteristic')

# %%
ui_allyears
# Out:
#                            Characteristic Total_x_x Uninsured Number_x_x  \
# 0                                   Total   323,668               27,462
# 1                           Family Status       NaN                  NaN
# 2                             In families   261,336               20,540
# 3                In unrelated subfamilies     1,069                  141
# 4                   Unrelated individuals    61,264                6,782
# ..                                    ...       ...                  ...
# 59                               Divorced    18,683                2,428
# 60                              Separated     4,200                  835
# 61                          Never Married    65,475               10,500
# 62                              Residence       NaN                  NaN
# 63  Inside metropolitan statistical areas   281,369               23,605
#
#     Uninsured Number MOE_x_x  Uninsured Percent_x_x  \
# 0                      630.0                    8.5
# 1                        NaN                    NaN
# 2                      551.0                    7.9
# 3                       38.0                   13.1
# 4                      263.0                   11.1
# ..                       ...                    ...
# 59                     125.0                   13.0
# 60                      92.0                   19.9
# 61                     331.0                   16.0
# 62                       NaN                    NaN
# 63                     592.0                    8.4
#
#     Uninsured Percent MOE_x_x Total_y_x Uninsured Number_y_x  \
# 0                         0.2   324,550               26,111
# 1                         NaN       NaN                  NaN
# 2                         0.2   262,991               19,480
# 3                         3.4       941                   89
# 4                         0.4    60,618                6,543
# ..                        ...       ...                  ...
# 59                        0.7    18,290                2,196
# 60                        2.0     3,802                  724
# 61                        0.5    67,065               10,528
# 62                        NaN       NaN                  NaN
# 63                        0.2   282,168               22,381
#
#     Uninsured Number MOE_y_x  Uninsured Percent_y_x  ...  Total_x_y  \
# 0                      657.0                    8.0  ...    325,638
# 1                        NaN                    NaN  ...        NaN
# 2                      586.0                    7.4  ...    261,847
# 3                       37.0                    9.4  ...      1,017
# 4                      265.0                   10.8  ...     62,774
# ..                       ...                    ...  ...        ...
# 59                     140.0                   12.0  ...     18,486
# 60                      78.0                   19.0  ...      3,738
# 61                     375.0                   15.7  ...     69,297
# 62                       NaN                    NaN  ...        NaN
# 63                     667.0                    7.9  ...    283,350
#
#    Uninsured Number_x_y Uninsured Number MOE_x_y  Uninsured Percent_x_y  \
# 0                27,957                    612.0                    8.6
# 1                   NaN                      NaN                    NaN
# 2                21,255                    521.0                    8.1
# 3                   137                     43.0                   13.5
# 4                 6,565                    270.0                   10.5
# ..                  ...                      ...                    ...
# 59                2,431                    145.0                   13.2
# 60                  756                     78.0                   20.2
# 61               11,090                    327.0                   16.0
# 62                  NaN                      NaN                    NaN
# 63               24,168                    608.0                    8.5
#
#     Uninsured Percent MOE_x_y  Total_y_y Uninsured Number_y_y  \
# 0                         0.2    328,074               27,187
# 1                         NaN        NaN                  NaN
# 2                         0.2    263,127               20,214
# 3                         3.8      1,024                  160
# 4                         0.4     63,923                6,812
# ..                        ...        ...                  ...
# 59                        0.7     18,138                2,273
# 60                        1.9      3,898                  739
# 61                        0.5     70,474               11,166
# 62                        NaN        NaN                  NaN
# 63                        0.2    285,654               23,704
#
#    Uninsured Number MOE_y_y  Uninsured Percent_y_y  Uninsured Percent MOE_y_y
# 0                     727.0                    8.3                        0.2
# 1                       NaN                    NaN                        NaN
# 2                     648.0                    7.7                        0.2
# 3                      53.0                   15.7                        4.5
# 4                     304.0                   10.7                        0.5
# ..                      ...                    ...                        ...
# 59                    140.0                   12.5                        0.7
# 60                     89.0                   19.0                        2.1
# 61                    373.0                   15.8                        0.5
# 62                      NaN                    NaN                        NaN
# 63                    729.0                    8.3                        0.2
#
# [64 rows x 21 columns]

# %%
pd.DataFrame.to_csv(ui_allyears)
# Out:
8,675",325.0,18.9,0.6,"44,897","7,977",333.0,17.8,0.7,"44,799","8,667",372.0,19.3,0.7,"46,845","9,130",398.0,19.5,0.8\r\n17,Region,,,,,,,,,,,,,,,,,,,,\r\n18,Northeast,"55,266","2,792",264.0,5.1,0.5,"55,080","2,611",202.0,4.7,0.4,"54,771","2,619",212.0,4.8,0.4,"56,065","2,954",241.0,5.3,0.4\r\n19,Midwest,"67,458","3,825",245.0,5.7,0.4,"67,486","3,846",283.0,5.7,0.4,"67,436","4,189",259.0,6.2,0.4,"67,933","3,762",251.0,5.5,0.4\r\n20,South,"123,391","14,878",444.0,12.1,0.4,"124,084","13,701",520.0,11.0,0.4,"125,396","14,741",445.0,11.8,0.4,"126,144","14,319",518.0,11.4,0.4\r\n21,West,"77,553","5,967",284.0,7.7,0.4,"77,900","5,953",308.0,7.6,0.4,"78,035","6,409",270.0,8.2,0.3,"77,933","6,152",311.0,7.9,0.4\r\n22,Household Income,,,,,,,,,,,,,,,,,,,,\r\n23,"Less than $25,000","43,320","5,976",274.0,13.8,0.6,"37,401","4,914",253.0,13.1,0.6,"41,274","5,942",330.0,14.4,0.7,"39,563","5,468",329.0,13.8,0.8\r\n24,"$25,000 to less than $50,000","59,133","7,255",335.0,12.3,0.5,"56,136","7,185",349.0,12.8,0.6,"55,310","6,945",350.0,12.6,0.6,"52,295","6,478",322.0,12.4,0.6\r\n25,"$50,000 to less than $75,000","55,304","5,939",319.0,10.7,0.5,"52,801","5,500",294.0,10.4,0.5,"52,757","6,000",297.0,11.4,0.5,"51,792","5,506",286.0,10.6,0.5\r\n26,"$75,000 to less than $100,000","44,539","3,162",214.0,7.1,0.5,"42,800","3,211",234.0,7.5,0.5,"42,567","3,394",237.0,8.0,0.5,"41,533","3,581",249.0,8.6,0.6\r\n27,"$100,000 to less than $125,000","34,142","1,924",181.0,5.6,0.5,"35,355","2,234",226.0,6.3,0.6,"34,538","2,364",219.0,6.8,0.6,"35,351","2,153",186.0,6.1,0.5\r\n28,"$125,000 to less than $150,000","23,291","1,143",135.0,4.9,0.6,"24,084",981,163.0,4.1,0. ...

# %%
uninsuredtotal_2018 = int(uninsured2018_csv['Uninsured Number'].values[0].replace(',', ''))
uninsuredtotal_2019 = int(uninsured2019_csv['Uninsured Number'].values[0].replace(',', ''))
uninsuredtotal_2020 = int(uninsured2020_csv['Uninsured Number'].values[0].replace(',', ''))
uninsuredtotal_2021 = int(uninsured2021_csv['Uninsured Number'].values[0].replace(',', ''))

years = ["2018", "2019", "2020", "2021"]
UItotals = [uninsuredtotal_2018, uninsuredtotal_2019, uninsuredtotal_2020, uninsuredtotal_2021]

# %%
year_unins=plt.plot(years,UItotals, marker="o")
plt.title("Uninsured Over Time")
plt.xlabel("Year")
plt.ylabel("Total # of Uninsured")

plt.savefig('yearunins_compare.png')
year_unins
