# %%
import pandas as pd
from sodapy import Socrata

# %%
#api info at https://dev.socrata.com/foundry/data.cdc.gov/9mfq-cb36
#table info https://data.cdc.gov/Case-Surveillance/United-States-COVID-19-Cases-and-Deaths-by-State-o/9mfq-cb36

client = Socrata("data.cdc.gov",None)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
df = client.get("9mfq-cb36", limit=30000)

# %%
covid_df = pd.DataFrame.from_records(results)

# %%
covid_df= covid_df.sort_values(by=["submission_date", "state"])
covid_df
# Out:
#                submission_date state tot_cases conf_cases prob_cases new_case  \
# 3725   2020-01-22T00:00:00.000    AL         0        0.0          0        0
# 10873  2020-01-22T00:00:00.000    AR         0        NaN        NaN        0
# 19422  2020-01-22T00:00:00.000    CA         0        0.0          0        0
# 13030  2020-01-22T00:00:00.000    CO         0        0.0          0        0
# 17053  2020-01-22T00:00:00.000    DC         0        NaN        NaN        0
# ...                        ...   ...       ...        ...        ...      ...
# 16387  2022-10-18T00:00:00.000    SC   1718563  1326050.0     392513      0.0
# 10159  2022-10-18T00:00:00.000    SD    262837        NaN        NaN      0.0
# 11654  2022-10-18T00:00:00.000    TN   2351660  1737249.0     614411      0.0
# 16137  2022-10-18T00:00:00.000    VA   2106527  1490236.0     616291    942.0
# 18065  2022-10-18T00:00:00.000    VI     23269        NaN        NaN     13.0
#
# ...

# %%
#test= covid_df["new_death"].isnull().sum()
#test= pd.to_numeric(covid_df["new_death"], errors="coerce").notnull().all()
test= (covid_df["new_death"].dtype == "object").sum()
test
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31248\435597704.py in <module>
#       1 #test= covid_df["new_death"].isnull().sum()
#       2 #test= pd.to_numeric(covid_df["new_death"], errors="coerce").notnull().all()
# ----> 3 test= (covid_df["new_death"].dtype == "object").sum()
#       4 test
#
# AttributeError: 'bool' object has no attribute 'sum'
