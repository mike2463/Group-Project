# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt

# %%
data = pd.read_csv('Resources/GDP.csv')
data.head()
# Out:
#          DATE      GDP
# 0  1947-01-01  243.164
# 1  1947-04-01  245.968
# 2  1947-07-01  249.585
# 3  1947-10-01  259.745
# 4  1948-01-01  265.742

# %%
pd.to_datetime(data['DATE'], format= '%Y-%m-%d' )
recent_gdp = data[(data['DATE']>='2018-01-01')]
#recent_gdp = recent_gdp.sort_values('GDP')
recent_gdp.dtypes
# Out:
# DATE     object
# GDP     float64
# dtype: object

# %%
recent_gdp['GDP'].describe()
# Out:
# count       20.000000
# mean     22350.462250
# std       1955.753811
# min      19636.731000
# 25%      20964.631000
# 50%      21621.369000
# 75%      23750.095250
# max      26137.992000
# Name: GDP, dtype: float64

# %%
x_axis = recent_gdp['DATE']

y_axis = recent_gdp['GDP'].sort_values(ascending=True)
plt.plot(x_axis,y_axis)
plt.xticks(x_axis, rotation = 90)
plt.ylabel('GDP (billions of dollars)', loc='center')
plt.xlabel('Quarters')
# Out:
# Text(0.5, 0, 'Quarters')

# %%
recent_gdp.pct_change(recent_gdp['GDP'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\micha\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:165, in _na_arithmetic_op(left, right, op, is_cmp)
#     164 try:
# --> 165     result = func(left, right)
#     166 except TypeError:
#
# File c:\Users\micha\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:241, in evaluate(op, a, b, use_numexpr)
#     239     if use_numexpr:
#     240         # error: "None" not callable
# --> 241         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     242 return _evaluate_standard(op, op_str, a, b)
#
# File c:\Users\micha\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:129, in _evaluate_numexpr(op, op_str, a, b)
#     128 if result is None:
# --> 129     result = _evaluate_standard(op, op_str, a, b)
#     131 return result
#
# ...
